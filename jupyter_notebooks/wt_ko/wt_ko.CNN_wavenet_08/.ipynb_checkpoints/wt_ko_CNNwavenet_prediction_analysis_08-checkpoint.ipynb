# %% [markdown]
# # WT vs KO APOBEC1 CNN WaveNet prediction analysis
#     21/02/2022
# Data have been produced by CtoUclassifier_pipe_currents_extraction_step pipeline.

# %%
# import basic modules
import os, sys

# add parent folder of the C_to_U_classifier_plus_min package to path in order to be loaded into the current session
sys.path.append("/lustrehome/afonzino")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from C_to_U_classifier_plus_min import utils

# %% [markdown]
# ### WT

# %%
# define input paths for CNN wavenet prediction on basecalling features
wt_dfCTaggr_filepath = "/lustre/bio_running/C_to_U_editing_minimap2_spliced/wt.model_CNN_wt_PlusMin/df_CT_predicted_aggregated_08.tsv"
ref_filepath = "/lustre/bio_running/C_to_U_editing/refs/GRCm39.genome.fa"

# %%
utils.plot_frequencies(reference_filepath=ref_filepath, 
                       df_aggregated_filepath=wt_dfCTaggr_filepath, 
                       title="WT - CNN WaveNet model",
                       save_folderpath="/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks/wt_ko/wt_ko.CNN_wavenet_08",
                       log=True,
                       offset=0,
                       native_color="cyan",
                       corrected_color="blue",
                       native_size=15,
                       corrected_size=10,
                       freq_threshold=0.01)
# Out:
# [2022-02-21 16:01:47.851704] Retrieving Contigs and lengths...
# [2022-02-21 16:01:48.336562] Merging dataframes for region chr1...
# [2022-02-21 16:03:31.131830] Merging finished....start plotting...
# [2022-02-21 16:05:13.581889] Merging dataframes for region chr2...
# [2022-02-21 16:06:47.529852] Merging finished....start plotting...
# [2022-02-21 16:08:21.987791] Merging dataframes for region chr3...
# [2022-02-21 16:09:51.800222] Merging finished....start plotting...
# [2022-02-21 16:11:18.096642] Merging dataframes for region chr4...
# [2022-02-21 16:12:43.399492] Merging finished....start plotting...
# [2022-02-21 16:14:08.471674] Merging dataframes for region chr5...
# [2022-02-21 16:15:31.157007] Merging finished....start plotting...
# [2022-02-21 16:16:53.915938] Merging dataframes for region chr6...
# [2022-02-21 16:18:16.245641] Merging finished....start plotting...
# [2022-02-21 16:19:37.011726] Merging dataframes for region chr7...
# ...

# %%
dfCTaggr = pd.read_table(wt_dfCTaggr_filepath)

# %%
plt.figure(figsize=(10,5))
sn.barplot(data=dfCTaggr[["Tfreq_native", "Tfreq_corrected"]])
plt.title("WT - CNN WaveNet model - CT frequency")
plt.ylabel("Frequency")
sn.despine(offset=10, trim=True)
plt.savefig("/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks_multi_thr/wt_ko/wt_ko.CNN_wavenet_08/wt.CNNwavenet.aggregated.barplot.tiff")
plt.show()

# %%
plt.figure(figsize=(10,5))
sn.boxplot(data=dfCTaggr[["Tfreq_native", "Tfreq_corrected"]])
plt.yscale("log")
plt.title("WT - CNN WaveNet model - CT frequency")
plt.ylabel("Frequency")
sn.despine(offset=10, trim=True)
plt.savefig("/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks_multi_thr/wt_ko/wt_ko.CNN_wavenet_08/wt.CNNwavenet.aggregated.boxplot.tiff")
plt.show()

# %%
dfCTaggr.Tfreq_native.describe()
# Out:
# count    337789.000000
# mean          0.036599
# std           0.054769
# min           0.000074
# 25%           0.010939
# 50%           0.019231
# 75%           0.042254
# max           1.000000
# Name: Tfreq_native, dtype: float64

# %%
dfCTaggr.Tfreq_corrected.describe()
# Out:
# count    337789.000000
# mean          0.004461
# std           0.017569
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Tfreq_corrected, dtype: float64

# %% [markdown]
# ### KO

# %%
# define input paths for CNN wavenet prediction on basecalling features
ko_dfCTaggr_filepath = "/lustre/bio_running/C_to_U_editing_minimap2_spliced/ko.model_CNN_ko_PlusMin/df_CT_predicted_aggregated_08.tsv"

# %%
utils.plot_frequencies(reference_filepath=ref_filepath, 
                       df_aggregated_filepath=ko_dfCTaggr_filepath, 
                       title="KO - CNN WaveNet model",
                       save_folderpath="/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks/wt_ko/wt_ko.CNN_wavenet_08",
                       log=True,
                       offset=0,
                       native_color="cyan",
                       corrected_color="blue",
                       native_size=15,
                       corrected_size=10,
                       freq_threshold=0.01)
# Out:
# [2022-02-21 18:52:34.463162] Retrieving Contigs and lengths...
# [2022-02-21 18:52:34.955040] Merging dataframes for region chr1...
# [2022-02-21 18:54:17.222613] Merging finished....start plotting...
# [2022-02-21 18:55:59.147212] Merging dataframes for region chr2...
# [2022-02-21 18:57:32.586393] Merging finished....start plotting...
# [2022-02-21 18:59:07.532738] Merging dataframes for region chr3...
# [2022-02-21 19:00:38.989826] Merging finished....start plotting...
# [2022-02-21 19:02:04.915416] Merging dataframes for region chr4...
# [2022-02-21 19:03:29.192090] Merging finished....start plotting...
# [2022-02-21 19:04:53.677385] Merging dataframes for region chr5...
# [2022-02-21 19:06:19.009201] Merging finished....start plotting...
# [2022-02-21 19:07:41.669133] Merging dataframes for region chr6...
# [2022-02-21 19:09:04.365569] Merging finished....start plotting...
# [2022-02-21 19:10:25.176719] Merging dataframes for region chr7...
# ...

# %%
dfCTaggr = pd.read_table(ko_dfCTaggr_filepath)

plt.figure(figsize=(10,5))
sn.barplot(data=dfCTaggr[["Tfreq_native", "Tfreq_corrected"]])
plt.title("KO - CNN WaveNet model - CT frequency")
plt.ylabel("Frequency")
sn.despine(offset=10, trim=True)
plt.savefig("/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks_multi_thr/wt_ko/wt_ko.CNN_wavenet_08/ko.CNN_wavenet_08.aggregated.barplot.tiff")
plt.show()

# %%
plt.figure(figsize=(10,5))
sn.boxplot(data=dfCTaggr[["Tfreq_native", "Tfreq_corrected"]])
plt.yscale("log")
plt.title("KO - CNN WaveNet model - CT frequency")
plt.ylabel("Frequency")
sn.despine(offset=10, trim=True)
plt.savefig("/lustre/bio_running/C_to_U_editing_minimap2_spliced/src_jupyter_notebooks_multi_thr//wt_ko/wt_ko.CNN_wavenet_08/ko.CNN_wavenet_08.aggregated.boxplot.tiff")
plt.show()

# %%
dfCTaggr.Tfreq_native.describe()
# Out:
# count    465907.000000
# mean          0.036833
# std           0.055159
# min           0.000066
# 25%           0.010870
# 50%           0.019231
# 75%           0.042553
# max           1.000000
# Name: Tfreq_native, dtype: float64

# %%
dfCTaggr.Tfreq_corrected.describe()
# Out:
# count    465907.000000
# mean          0.003361
# std           0.014166
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Tfreq_corrected, dtype: float64
